# %% [markdown]
# # Read the data

# %% [markdown]
# Stack Overflow’s annual Developer Survey is a large and comprehensive survey of people who code around the world. Each year, they field a survey covering everything from developers’ favorite technologies to their job preferences. Download the data from https://www.kaggle.com/aitzaz/stack-overflow-developer-survey-2020.

# %%
import pandas as pd
import numpy as np
import zipfile

zf = zipfile.ZipFile('stack_overflow_2020.zip') 
df = pd.read_csv(zf.open('developer_survey_2020/survey_results_public.csv'))

columns_to_keep = ['Respondent', 'Country', 'Employment', 'Ethnicity', 'Gender', 'YearsCode', 'EdLevel', 'JobSat', 'LanguageWorkedWith', 'Age']
df = df.filter(items=columns_to_keep)

# %% [markdown]
# # Glimpse the data

# %%
print(df.shape)
df.head()
# Out:
# (64461, 10)
#    Respondent             Country  \
# 0           1             Germany
# 1           2      United Kingdom
# 2           3  Russian Federation
# 3           4             Albania
# 4           5       United States
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
#
#                       Ethnicity Gender YearsCode  \
# 0  White or of European descent    Man        36
# 1                           NaN    NaN         7
# 2                           NaN    NaN         4
# 3  White or of European descent    Man         7
# 4  White or of European descent    Man        15
#
#                                            EdLevel                 JobSat  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     Slightly satisfied
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)      Very dissatisfied
# 2                                              NaN                    NaN
# 3  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  Slightly dissatisfied
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)                    NaN
#
#          LanguageWorkedWith   Age
# 0    C#;HTML/CSS;JavaScript   NaN
# 1          JavaScript;Swift   NaN
# 2  Objective-C;Python;Swift   NaN
# 3                       NaN  25.0
# 4         HTML/CSS;Ruby;SQL  31.0

# %% [markdown]
# # Check Dtypes

# %%
df.dtypes
# Out:
# Respondent              int64
# Country                object
# Employment             object
# Ethnicity              object
# Gender                 object
# YearsCode              object
# EdLevel                object
# JobSat                 object
# LanguageWorkedWith     object
# Age                   float64
# dtype: object

# %%
df.YearsCode.unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].replace('Less than 1 year', 0)
df['YearsCode'] = df['YearsCode'].replace('More than 50 years', 50)
df['YearsCode'] = df['YearsCode'].astype('float64')

# %%
df.dtypes
# Out:
# Respondent              int64
# Country                object
# Employment             object
# Ethnicity              object
# Gender                 object
# YearsCode             float64
# EdLevel                object
# JobSat                 object
# LanguageWorkedWith     object
# Age                   float64
# dtype: object

# %% [markdown]
# # Check missing data

# %%
df.isnull().sum()
# Out:
# Respondent                0
# Country                 389
# Employment              607
# Ethnicity             18513
# Gender                13904
# YearsCode              6777
# EdLevel                7030
# JobSat                19267
# LanguageWorkedWith     7083
# Age                   19015
# dtype: int64

# %% [markdown]
# # Categoricals

# %%
age_bins = [0, 18, 24, 34, 44, 54, 64, 100]

age_labels = ['17 years or younger', '18 - 24 years old', '25 - 34 years old', '35 - 44 years old', '45 - 54 years old', '55 - 64 years old', '65 years or older']

df['age_cat'] = pd.cut(df['Age'], 
                        bins=age_bins,
                        labels=age_labels,
                        right=True)

# %%
df[df.Age.notnull()][['Age', 'age_cat']]
# Out:
#         Age              age_cat
# 3      25.0    25 - 34 years old
# 4      31.0    25 - 34 years old
# 7      36.0    35 - 44 years old
# 8      30.0    25 - 34 years old
# 9      22.0    18 - 24 years old
# ...     ...                  ...
# 64426  22.0    18 - 24 years old
# 64427  34.0    25 - 34 years old
# 64430  38.0    35 - 44 years old
# 64433  64.0    55 - 64 years old
# 64441  17.0  17 years or younger
#
# [45446 rows x 2 columns]

# %% [markdown]
# <b>Number of programmers in each bucket<b>

# %%
df.age_cat.value_counts()
# Out:
# 25 - 34 years old      20866
# 18 - 24 years old      10026
# 35 - 44 years old       8674
# 45 - 54 years old       2807
# 17 years or younger     1844
# 55 - 64 years old        957
# 65 years or older        271
# Name: age_cat, dtype: int64

# %% [markdown]
# # Clean labels

# %%
df.EdLevel.unique()
# Out:
# array(['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', nan,
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Professional degree (JD, MD, etc.)',
#        'Some college/university study without earning a degree',
#        'Associate degree (A.A., A.S., etc.)',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Primary/elementary school',
#        'I never completed any formal education'], dtype=object)

# %%
df['EdLevel'] = df['EdLevel'].str.replace(r"\(.*\)", "")
df.EdLevel.unique()
# Out:
# array(['Master’s degree ', 'Bachelor’s degree ', nan, 'Secondary school ',
#        'Professional degree ',
#        'Some college/university study without earning a degree',
#        'Associate degree ', 'Other doctoral degree ',
#        'Primary/elementary school',
#        'I never completed any formal education'], dtype=object)

# %% [markdown]
# <b>Years coding and Age for each education level<b>

# %%
df[['EdLevel', 'YearsCode', 'Age']].groupby('EdLevel').mean().sort_values(by='YearsCode', ascending=False)
# Out:
#                                                     YearsCode        Age
# EdLevel
# Other doctoral degree                               21.367754  39.428680
# Master’s degree                                     15.207951  33.721334
# Professional degree                                 15.177835  34.743719
# Some college/university study without earning a...  12.892907  30.825112
# Associate degree                                    12.556593  31.516227
# Bachelor’s degree                                   12.048921  30.431446
# I never completed any formal education               9.667431  29.951220
# Secondary school                                     8.162622  23.972902
# Primary/elementary school                            6.584158  20.433333

# %% [markdown]
# # Melt

# %%
df['LanguageWorkedWith'].unique()
# Out:
# array(['C#;HTML/CSS;JavaScript', 'JavaScript;Swift',
#        'Objective-C;Python;Swift', ...,
#        'Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;JavaScript;Kotlin;Python;Ruby;Rust;SQL',
#        'Bash/Shell/PowerShell;C#;C++;HTML/CSS;JavaScript;Kotlin;PHP;SQL;VBA',
#        'Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;JavaScript;Objective-C;Python;Swift'],
#       dtype=object)

# %% [markdown]
# <b>1) Create a column for each programming language in existence<b>

# %%
# Extracting Languages
languages = []
for text in df['LanguageWorkedWith'].dropna().values.tolist():
    temp = text.split(';')
    for lang in temp:
        if lang not in languages:
            languages.append(lang.strip())
            
print(languages)
# Out:
# ['C#', 'HTML/CSS', 'JavaScript', 'Swift', 'Objective-C', 'Python', 'Ruby', 'SQL', 'Java', 'PHP', 'C', 'TypeScript', 'Bash/Shell/PowerShell', 'Kotlin', 'R', 'VBA', 'Perl', 'Scala', 'C++', 'Go', 'Haskell', 'Rust', 'Dart', 'Julia', 'Assembly']

# %%
for lang in languages:
    df[lang] = np.where(df['LanguageWorkedWith'].str.contains(lang, na=False, regex=False), True, False)

df.head()
# Out:
#    Respondent             Country  \
# 0           1             Germany
# 1           2      United Kingdom
# 2           3  Russian Federation
# 3           4             Albania
# 4           5       United States
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Employed full-time
# 2                                                NaN
# 3                                                NaN
# 4                                 Employed full-time
#
#                       Ethnicity Gender  YearsCode             EdLevel  \
# 0  White or of European descent    Man       36.0    Master’s degree
# 1                           NaN    NaN        7.0  Bachelor’s degree
# 2                           NaN    NaN        4.0                 NaN
# 3  White or of European descent    Man        7.0    Master’s degree
# 4  White or of European descent    Man       15.0  Bachelor’s degree
#
#                   JobSat        LanguageWorkedWith   Age  ...    VBA   Perl  \
# 0     Slightly satisfied    C#;HTML/CSS;JavaScript   NaN  ...  False  False
# 1      Very dissatisfied          JavaScript;Swift   NaN  ...  False  False
# 2                    NaN  Objective-C;Python;Swift   NaN  ...  False  False
# 3  Slightly dissatisfied                       NaN  25.0  ...  False  False
# 4                    NaN         HTML/CSS;Ruby;SQL  31.0  ...  False  False
#
#    Scala    C++     Go  Haskell   Rust   Dart  Julia  Assembly
# 0  False  False  False    False  False  False  False     False
# 1  False  False  False    False  False  False  False     False
# 2  False  False  False    False  False  False  False     False
# 3  False  False  False    False  False  False  False     False
# 4  False  False  False    False  False  False  False     False
#
# [5 rows x 36 columns]

# %%
df.iloc[0]
# Out:
# Respondent                                                               1
# Country                                                            Germany
# Employment               Independent contractor, freelancer, or self-em...
# Ethnicity                                     White or of European descent
# Gender                                                                 Man
# YearsCode                                                               36
# EdLevel                                                   Master’s degree
# JobSat                                                  Slightly satisfied
# LanguageWorkedWith                                  C#;HTML/CSS;JavaScript
# Age                                                                    NaN
# age_cat                                                                NaN
# C#                                                                    True
# HTML/CSS                                                              True
# JavaScript                                                            True
# Swift                                                                False
# Objective-C                                                          False
# Python                                                               False
# Ruby                                                                 False
# SQL                                                                  False
# Java                                                                  True
# PHP                                                                  False
# C                                                                     True
# TypeScript                                                           False
# Bash/Shell/PowerShell                                                False
# Kotlin                                                               False
# R                                                                    False
# VBA                                                                  False
# Perl                                                                 False
# Scala                                                                False
# C++                                                                  False
# Go                                                                   False
# Haskell                                                              False
# Rust                                                                 False
# Dart                                                                 False
# Julia                                                                False
# Assembly                                                             False
# Name: 0, dtype: object

# %% [markdown]
# <b>2) Pandas melt()<b>

# %%
melt_df = df.melt(id_vars=columns_to_keep, value_vars=languages, var_name='language', value_name='language_value')

# %%
melt_df[melt_df.Respondent == 1].head()
# Out:
#         Respondent  Country  \
# 0                1  Germany
# 64461            1  Germany
# 128922           1  Germany
# 193383           1  Germany
# 257844           1  Germany
#
#                                                Employment  \
# 0       Independent contractor, freelancer, or self-em...
# 64461   Independent contractor, freelancer, or self-em...
# 128922  Independent contractor, freelancer, or self-em...
# 193383  Independent contractor, freelancer, or self-em...
# 257844  Independent contractor, freelancer, or self-em...
#
#                            Ethnicity Gender  YearsCode           EdLevel  \
# 0       White or of European descent    Man       36.0  Master’s degree
# 64461   White or of European descent    Man       36.0  Master’s degree
# 128922  White or of European descent    Man       36.0  Master’s degree
# 193383  White or of European descent    Man       36.0  Master’s degree
# 257844  White or of European descent    Man       36.0  Master’s degree
#
#                     JobSat      LanguageWorkedWith  Age     language  \
# 0       Slightly satisfied  C#;HTML/CSS;JavaScript  NaN           C#
# 64461   Slightly satisfied  C#;HTML/CSS;JavaScript  NaN     HTML/CSS
# 128922  Slightly satisfied  C#;HTML/CSS;JavaScript  NaN   JavaScript
# 193383  Slightly satisfied  C#;HTML/CSS;JavaScript  NaN        Swift
# 257844  Slightly satisfied  C#;HTML/CSS;JavaScript  NaN  Objective-C
#
#         language_value
# 0                 True
# 64461             True
# 128922            True
# 193383           False
# 257844           False

# %% [markdown]
# <b>Figure out the most commonly known programming languages<b>

# %%
melt_df = melt_df.loc[melt_df['language_value'] == True]
melt_df[['language', 'language_value']].groupby(['language']).count().sort_values(by=['language_value'], ascending=False)
# Out:
#                        language_value
# language
# C                               46769
# Java                            45749
# JavaScript                      38822
# HTML/CSS                        36181
# SQL                             31413
# Python                          25287
# Bash/Shell/PowerShell           18980
# C#                              18041
# PHP                             15007
# TypeScript                      14578
# C++                             13707
# R                                9293
# Go                               5038
# Kotlin                           4468
# Ruby                             4046
# Assembly                         3553
# VBA                              3499
# Swift                            3397
# Rust                             2929
# Objective-C                      2340
# Dart                             2280
# Scala                            2052
# Perl                             1796
# Haskell                          1222
# Julia                             519

# %% [markdown]
# <b>Programing languages are used by people very satisfied with their jobs<b>

# %%
job_sat = melt_df.groupby(['JobSat', 'language']).size().to_frame('count')
job_sat
# Out:
#                                                           count
# JobSat                             language
# Neither satisfied nor dissatisfied Assembly                 245
#                                    Bash/Shell/PowerShell   1645
#                                    C                       4290
#                                    C#                      1770
#                                    C++                     1083
# ...                                                         ...
# Very satisfied                     SQL                     7911
#                                    Scala                    590
#                                    Swift                    871
#                                    TypeScript              4203
#                                    VBA                      821
#
# [125 rows x 1 columns]

# %%
job_sat.loc['Very satisfied'].sort_values(by='count', ascending=False)
# Out:
#                        count
# language
# C                      11175
# Java                   10986
# JavaScript              9619
# HTML/CSS                8671
# SQL                     7911
# Python                  6039
# Bash/Shell/PowerShell   5435
# C#                      4537
# TypeScript              4203
# PHP                     3295
# C++                     2802
# R                       2505
# Go                      1397
# Ruby                    1202
# Kotlin                  1088
# Swift                    871
# VBA                      821
# Rust                     732
# Assembly                 707
# Objective-C              636
# Scala                    590
# Perl                     512
# Dart                     449
# Haskell                  268
# Julia                    133
